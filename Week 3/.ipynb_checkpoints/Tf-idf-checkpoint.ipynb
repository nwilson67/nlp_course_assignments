# %%
import scikitlearn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <module>
# ----> 1 import scikitlearn
#
# ModuleNotFoundError: No module named 'scikitlearn'

# %%
corpus = [ 'This is the first document.', 'This document is the second document.', 'And this is the third one.', 'Is this the first USU document?', ] vectorizer_default = TfidfVectorizer() vectorizer_smoothed = TfidfVectorizer(norm=None) vectorizer_traditional = TfidfVectorizer(norm=None, smooth_idf=False) X = { 'default': vectorizer_default.fit_transform(corpus), 'smoothed': vectorizer_smoothed.fit_transform(corpus), 'traditional': vectorizer_traditional.fit_transform(corpus) }
# Out:
#   Input In [2]
#     corpus = [ 'This is the first document.', 'This document is the second document.', 'And this is the third one.', 'Is this the first USU document?', ] vectorizer_default = TfidfVectorizer() vectorizer_smoothed = TfidfVectorizer(norm=None) vectorizer_traditional = TfidfVectorizer(norm=None, smooth_idf=False) X = { 'default': vectorizer_default.fit_transform(corpus), 'smoothed': vectorizer_smoothed.fit_transform(corpus), 'traditional': vectorizer_traditional.fit_transform(corpus) }
#                                                                                                                                                           ^
# SyntaxError: invalid syntax

# %%
import sklearn

# %%
corpus = [ 'This is the first document.', 'This document is the second document.', 'And this is the third one.', 'Is this the first USU document?', ]

# %%
vectorizer_default = TfidfVectorizer()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <module>
# ----> 1 vectorizer_default = TfidfVectorizer()
#
# NameError: name 'TfidfVectorizer' is not defined

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
 vectorizer_default = TfidfVectorizer()

# %%
vectorizer_smoothed = TfidfVectorizer(norm=None)

# %%
vectorizer_traditional = TfidfVectorizer(norm=None, smooth_idf=False)

# %%
X = { 'default': vectorizer_default.fit_transform(corpus), 'smoothed': vectorizer_smoothed.fit_transform(corpus), 'traditional': vectorizer_traditional.fit_transform(corpus) }
