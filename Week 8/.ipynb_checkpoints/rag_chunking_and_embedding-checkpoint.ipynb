# %%
import mailbox
from bs4 import BeautifulSoup
import re

documents = []
mbox = mailbox.mbox(r"C:\Users\Nathan\Downloads\takeout-20251111T021856Z-1-001\Takeout\Mail\homework.mbox")

for message in mbox:
    print(message["subject"])

    payload = message.get_payload()

    # === MULTIPART EMAIL (HTML + attachments + text) ===
    if isinstance(payload, list):
        for part in message.walk():
            content_type = part.get_content_type()
            content_disposition = str(part.get("Content-Disposition", ""))

            # Only handle readable parts
            if content_type in ["text/plain", "text/html"] and "attachment" not in content_disposition:
                raw_bytes = part.get_payload(decode=True)
                if raw_bytes:
                    try:
                        text = raw_bytes.decode(part.get_content_charset() or "utf-8", errors="ignore")
                    except Exception:
                        text = str(raw_bytes)

                    soup = BeautifulSoup(text, "lxml")
                    text = soup.get_text(separator="\n", strip=True)
                    cleaned_text = re.sub(r'=(0D|0A|09|E2|80|8C)', '', text)
                    cleaned_text = cleaned_text.replace("=", "")
                    documents.append(cleaned_text)

    # === SIMPLE EMAIL (no MIME parts) ===
    elif isinstance(payload, str):
        soup = BeautifulSoup(payload, "lxml")
        text = soup.get_text(separator="\n", strip=True)
        cleaned_text = re.sub(r'=(0D|0A|09|E2|80|8C)', '', text)
        cleaned_text = cleaned_text.replace("=", "")
        documents.append(cleaned_text)

    else:
        raise TypeError("Unexpected payload type")

    print(" ")

print(f"\n✅ Extracted {len(documents)} messages.")
# Out:
# Halloween Information
#
# IMPORTANT (PLEASE READ) Safety & Cleaning Inspections
#
# Chapter Seventeen: In Which The Corn Surrenders To Us
#
# Chapter Eighteen: In Which Teaching Is Done
#
# Nathan, =?UTF-8?B?eW914oCZcmUgaW4hIPCfjok=?= famfam sibling secret
#  santa starts now!
#
# =?iso-8859-1?Q?Save_on_Apple=AE!_USU_Campus_Store_Fall_Tech_Sale?=
#
# Papa Murphy's Order Received
#
# Parking at Aggie Village
#
# Final Updated List for Trick-or-Treat
#
# Thank you for your Steam purchase!
#
# Nathan, your order is confirmed.
#
# =?UTF-8?Q?Join_us_for_Homecoming_=E2=80=93_Discounted_Tickets_for_Alumni!?=
#
#
# ✅ Extracted 23 messages.

# %%
for i, text in enumerate(documents):
    print(f"------------------------------ Document {i} ------------------------------")
    print(text)
    print(" ")
# Out:
# ------------------------------ Document 0 ------------------------------
# Hello Family Housing Community,
#
# I have attached a flyer that includes the list of units that have signed up to hand out candy. We have a total of 20 confirmed trick-or-treaters, but there is a possibility more may join in that evening!
#
# It will take place from 5pm-7pm on Friday, October 31st.
#
# For any that would not like their door to be knocked on that evening, you may consider turning off your porch light.
#
# Thank you for participating in our last minute Halloween Activity!
# Please reach out with any questions.
#
# Happy Halloween,
#
# Hana Robison
# Assistant Area Coordinator
# hana.kim@usu.edu
# 801.901.0968
#
#
#
#
# Get Outlook for Mac
#
# ------------------------------ Document 1 ------------------------------
# Hello Family Housing Community,
# ...

# %%
from sentence_transformers import SentenceTransformer

# 1. Load a pretrained Sentence Transformer model
model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# C:\Users\Nathan\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Nathan\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
# 2. Calculate embeddings by calling model.encode()
embeddings = model.encode(documents)
print(embeddings.shape)
# Out:
# (23, 384)

# %%
len(documents)
# Out:
# 23

# %%
query = model.encode(["Are there any conversations about a host family?"])

# %%
similarities = model.similarity(query, embeddings)

# %%
len(similarities[0])
# Out:
# 23

# %%
similarities[0].argmax()
# Out:
# tensor(0)

# %%
similarities[0]
# Out:
# tensor([ 0.2047,  0.2047,  0.0903,  0.0879,  0.1884,  0.1961,  0.1195,  0.1258,
#          0.1614,  0.2010,  0.0326,  0.0373,  0.0199,  0.0018,  0.0018,  0.0482,
#          0.0482,  0.0097, -0.0011,  0.0317, -0.0076,  0.0985,  0.1015])

# %%
print(documents[12])
# Out:
# Order Confirmation
#
# PAPA
#  MURPHY'S N MAIN (LOGAN, UT)
# 618 North Main Street, Logan,
# 							UTA084321
# (435)
# 							755-0808
# Order #
# 							39429127876116481
# (Note: You do not need this number to pickup)
# Customer Name:
# Nathan W
# ilson
# Customer Email:
# shadownate12@gmail.com
# <
# /tr>
# Customer Contact Number:
# 12087054400
# Payment Method: Credit Card Mastercard x-1318
# ORDER FOR
# 							 20
# 							      PICKUP
# Order ready at
# 6:52 PM
# ,
# 									TODAY (MONDAY, 11/10/2025)
# Please call the store for order or delivery support.
# We'll have your online order ready
#  for you at the Order Pickup area.
# Check out our
# Baking Instructions
# for tips and tricks that make bak
# ing a perfect pizza at home as easy as eating it.
# 1 x MySLICE Reward $1 Medium 1-Top
# ping
# Orig
# inal
# Medium (12")
# (1 x $12.00)
# 3D
# $12.00
# Whole
# Traditional Red
# Regular
# Pepperoni - Regular
# <
# /td>
# SUBTOTAL
# $12.00A0
# REDEEMED:
# ...

# %%
import os
from google import genai
from dotenv import load_dotenv

# loading variables from .env file
load_dotenv()
# Out:
# False

# %%
user_question = "Have I ordered from Papa Murphys?"
document = documents[12]
user_query = f"""
    Here is question from the user: {user_question}.
    
    Here is the closest matching document related to the question:
    <document>
    {document}
    </document>

    Use <document> to help answer the question.
    """

# %%
user_query
# Out:
# '\n    Here is question from the user: Have I ordered from Papa Murphys?.\n    \n    Here is the closest matching document related to the question:\n    <document>\n    Order Confirmation\n\nPAPA\n MURPHY\'S N MAIN (LOGAN, UT)\n618 North Main Street, Logan,\n\t\t\t\t\t\t\tUTA084321\n(435)\n\t\t\t\t\t\t\t755-0808\nOrder #\n\t\t\t\t\t\t\t39429127876116481\n(Note: You do not need this number to pickup)\nCustomer Name:\nNathan W\nilson\nCustomer Email:\nshadownate12@gmail.com\n<\n/tr>\nCustomer Contact Number:\n12087054400\nPayment Method: Credit Card Mastercard x-1318\nORDER FOR\n\t\t\t\t\t\t\t 20\n\t\t\t\t\t\t\t      PICKUP\nOrder ready at\n6:52 PM\n,\n\t\t\t\t\t\t\t\t\tTODAY (MONDAY, 11/10/2025)\nPlease call the store for order or delivery support.\nWe\'ll have your online order ready\n for you at the Order Pickup area.\nCheck out our\nBaking Instructions\nfor tips and tricks that make bak\ning a perfect pizza at home as easy as eating it.\n1 x MySLICE Reward $1 Medium 1-Top\nping\nOr
# ...

# %%
api_key = os.getenv("google_ai")
client = genai.Client(api_key=api_key)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    config=genai.types.GenerateContentConfig(
        system_instruction="You are a helpful school assistant answering questions about Elementary School"
    ),
    contents=user_query
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [60], in <module>
#       1 api_key = os.getenv("google_ai")
# ----> 2 client = genai.Client(api_key=api_key)
#       4 response = client.models.generate_content(
#       5     model="gemini-2.5-flash",
#       6     config=genai.types.GenerateContentConfig(
#    (...)
#       9     contents=user_query
#      10 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\genai\client.py:271, in Client.__init__(self, vertexai, api_key, credentials, project, location, debug_config, http_options)
#     268   else:
#     269     http_options = HttpOptions(base_url=base_url)
# --> 271 self._api_client = self._get_api_client(
#     272     vertexai=vertexai,
#     273     api_key=api_key,
#     274     credentials=credentials,
#     275     project=project,
#     276     location=location,
# ...

# %%
print(response.text)
# Out:
# Yes, according to the document, they are still looking for a host family **this year**. They need a family to host Adelie Minel, an intern from France, for either the full school year or just half of the year.

# %% [markdown]
# #### Voyage AI

# %%
# !pip install voyageai
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dotenv import load_dotenv

# loading variables from .env file
load_dotenv()
# Out:
# False

# %%
import voyageai

vo = voyageai.Client(api_key="pa-Yy0S7RHDcME3SUDXYTjMwhqZcqi17-TbdqdiDze-gS0")
# This will automatically use the environment variable VOYAGE_API_KEY.
# Alternatively, you can use vo = voyageai.Client(api_key="<your secret key>")

result = vo.embed(["hello world"], model="voyage-3.5")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [67], in <module>
# ----> 1 import voyageai
#       3 vo = voyageai.Client()
#       4 # This will automatically use the environment variable VOYAGE_API_KEY.
#       5 # Alternatively, you can use vo = voyageai.Client(api_key="<your secret key>")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\voyageai\__init__.py:29, in <module>
#      27 from voyageai.client import Client
#      28 from voyageai.client_async import AsyncClient
# ---> 29 from voyageai.embeddings_utils import (
#      30     get_embedding,
#      31     get_embeddings,
#      32     aget_embedding,
#      33     aget_embeddings,
#      34 )
#      36 if TYPE_CHECKING:
#      37     import requests
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\voyageai\embeddings_utils.py:26, in <module>
# ...

# %%
import os
from voyageai.client import Client
vo = Client(api_key=os.environ.get("VOYAGE_API_KEY"))

import numpy as np

# Initialize client
vo = voyageai.Client(api_key=os.environ.get("VOYAGE_API_KEY"))

# Make sure your documents is a list of strings
# documents = ["First email text", "Second email text", ...]

# Embed the documents
documents_embeddings = vo.embed(
    documents, model="voyage-3.5", input_type="document"
).embeddings

print(f"✅ Created embeddings for {len(documents_embeddings)} documents.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [57], in <module>
#       1 import os
#       2 from voyageai.client import Client
# ----> 3 vo = Client(api_key=os.environ.get("VOYAGE_API_KEY"))
#       5 import numpy as np
#       7 # Initialize client
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\voyageai\client.py:36, in Client.__init__(self, api_key, max_retries, timeout)
#      30 def __init__(
#      31     self,
#      32     api_key: Optional[str] = None,
#      33     max_retries: int = 0,
#      34     timeout: Optional[float] = None,
#      35 ) ->None:
# ---> 36     super().__init__(api_key, max_retries, timeout)
#      38     self.retry_controller = Retrying(
#      39         reraise=True,
#      40         stop=stop_after_attempt(max_retries),
#    (...)
#      46         ),
#      47     )
#
# ...

# %%
len(documents_embeddings)
# Out:
# 47

# %%
type(documents_embeddings)
# Out:
# list

# %%
query_embedding = vo.embed(['Anything I need to know for the new year?'], model="voyage-3.5", input_type="query").embeddings[0]

# %%
similarities = np.dot(documents_embeddings, query_embedding)

retrieved_id = np.argmax(similarities, n=2)
print(documents[retrieved_id])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [61], in <module>
#       1 similarities = np.dot(documents_embeddings, query_embedding)
# ----> 3 retrieved_id = np.argmax(similarities, n=2)
#       4 print(documents[retrieved_id])
#
# TypeError: argmax() got an unexpected keyword argument 'n'

# %%
np.argsort(similarities)[-2:]
# Out:
# array([ 0, 29])

# %%
print(documents[0])
# Out:
# Dear Panda Families,
# Welcome to May! We are excited for all the fun activities and are very grateful for all the hours of volunteer work that our PTA donates!
# We would like to thank you for your generosity during teacher appreciation week. This was such a fun week and the teachers are really grateful for all of your thoughtfulness. We love working in this community and count ourselves lucky to be able to teach your children!
# Upcoming Event Information:
# We made it to 2 Million Minutes read as a school! As a reward the student body will be participating in the Fire Hose Down! We really appreciate our reading committee and all the work that they have put in to help motivate our students to read and for getting this event scheduled. We would also like to thank the Fire Department for donating their resources and time! Please remember that if you are coming to watch this event, please do not park in our loading zone.
# ...

# %%
similarities
# Out:
# array([0.30025396, 0.1997721 , 0.26953188, 0.25097994, 0.1765615 ,
#        0.1986658 , 0.21245838, 0.19987829, 0.20205639, 0.27063635,
#        0.29624655, 0.19389917, 0.22399278, 0.24054407, 0.23990296,
#        0.24439417, 0.25550678, 0.17823361, 0.27823684, 0.2017699 ,
#        0.20195827, 0.25633646, 0.24713979, 0.26287541, 0.19851785,
#        0.2027447 , 0.22549598, 0.19120765, 0.29577271, 0.31118113,
#        0.20195249, 0.20513479, 0.24169579, 0.19982874, 0.19773493,
#        0.16795824, 0.24560727, 0.22911326, 0.23990296, 0.29779386,
#        0.20202481, 0.26693395, 0.28194348, 0.2152681 , 0.1978584 ,
#        0.2645503 , 0.22181155])

# %% [markdown]
# https://docs.voyageai.com/docs/quickstart-tutorial
